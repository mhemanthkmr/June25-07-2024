# %%
import pandas

# %%
import pandas as pd

# %%
data = pd.read_csv("tips.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         238 non-null    object
#  2   sex         242 non-null    object
#  3   smoker      243 non-null    object
#  4   day         241 non-null    object
#  5   time        243 non-null    object
#  6   size        241 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 13.5+ KB

# %%
data.head()
# Out:
#    total_bill     tip     sex smoker     day    time  size
# 0       16.99  Female      No    Sun  Dinner     NaN   NaN
# 1       10.34    1.66    Male     No     NaN  Dinner   3.0
# 2       21.01     3.5    Male     No     Sun  Dinner   3.0
# 3       23.68    Male      No    Sun  Dinner       2   NaN
# 4       24.59    3.61  Female     No     Sun  Dinner   4.0

# %%
data.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner   3.0
# 240       27.18     2  Female    Yes   Sat  Dinner   2.0
# 241       22.67     2    Male    Yes   Sat  Dinner   2.0
# 242       17.82  1.75    Male     No   Sat  Dinner   2.0
# 243       18.78     3  Female     No  Thur  Dinner   2.0

# %%
data.describe()
# Out:
#        total_bill        size
# count  244.000000  241.000000
# mean    19.732336    2.576763
# std      8.970230    0.954878
# min      1.960000    1.000000
# 25%     13.277500    2.000000
# 50%     17.795000    2.000000
# 75%     24.127500    3.000000
# max     50.810000    6.000000

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data['smoker']
# Out:
# 0      Sun
# 1       No
# 2       No
# 3      Sun
# 4       No
#       ...
# 239     No
# 240    Yes
# 241    Yes
# 242     No
# 243     No
# Name: smoker, Length: 244, dtype: object

# %%
data.isnull().sum()
# Out:
# total_bill    0
# tip           6
# sex           2
# smoker        1
# day           3
# time          1
# size          3
# dtype: int64

# %%
data.head(20)
# Out:
#     total_bill     tip     sex smoker     day    time  size
# 0        16.99  Female      No    Sun  Dinner     NaN   NaN
# 1        10.34    1.66    Male     No     NaN  Dinner   3.0
# 2        21.01     3.5    Male     No     Sun  Dinner   3.0
# 3        23.68    Male      No    Sun  Dinner       2   NaN
# 4        24.59    3.61  Female     No     Sun  Dinner   4.0
# 5        25.29    4.71    Male     No     NaN  Dinner   4.0
# 6         8.77       2    Male     No     Sun  Dinner   2.0
# 7        26.88    3.12    Male     No     Sun  Dinner   4.0
# 8         1.96    Male      No    Sun  Dinner       2   NaN
# 9        14.78    3.23    Male     No     NaN  Dinner   2.0
# 10       10.27     NaN    Male     No     Sun  Dinner   2.0
# 11       35.26       5  Female     No     Sun  Dinner   4.0
# 12       15.42    1.57    Male     No     Sun  Dinner   2.0
# 13       18.43       3    Male     No     Sun  Dinner   4.0
# 14       14.83    3.02  Female     No     Sun  Dinner   2.0
# ...

# %%
data.shape
# Out:
# (244, 7)

# %%
data
# Out:
#      total_bill     tip     sex smoker     day    time  size
# 0         16.99  Female      No    Sun  Dinner     NaN   NaN
# 1         10.34    1.66    Male     No     NaN  Dinner   3.0
# 2         21.01     3.5    Male     No     Sun  Dinner   3.0
# 3         23.68    Male      No    Sun  Dinner       2   NaN
# 4         24.59    3.61  Female     No     Sun  Dinner   4.0
# ..          ...     ...     ...    ...     ...     ...   ...
# 239       29.03    5.92    Male     No     Sat  Dinner   3.0
# 240       27.18       2  Female    Yes     Sat  Dinner   2.0
# 241       22.67       2    Male    Yes     Sat  Dinner   2.0
# 242       17.82    1.75    Male     No     Sat  Dinner   2.0
# 243       18.78       3  Female     No    Thur  Dinner   2.0
#
# [244 rows x 7 columns]

# %%
# b1=data.dropna()
# print(b1.shape)
# print(data.shape)

# %%
#data.dropna(inplace =True)
data. fillna(0,inplace=True)

# %%
data
# Out:
#      total_bill     tip     sex smoker     day    time  size
# 0         16.99  Female      No    Sun  Dinner       0   0.0
# 1         10.34    1.66    Male     No       0  Dinner   3.0
# 2         21.01     3.5    Male     No     Sun  Dinner   3.0
# 3         23.68    Male      No    Sun  Dinner       2   0.0
# 4         24.59    3.61  Female     No     Sun  Dinner   4.0
# ..          ...     ...     ...    ...     ...     ...   ...
# 239       29.03    5.92    Male     No     Sat  Dinner   3.0
# 240       27.18       2  Female    Yes     Sat  Dinner   2.0
# 241       22.67       2    Male    Yes     Sat  Dinner   2.0
# 242       17.82    1.75    Male     No     Sat  Dinner   2.0
# 243       18.78       3  Female     No    Thur  Dinner   2.0
#
# [244 rows x 7 columns]

# %%
data.loc[4,'day']

data.iloc[7,3]
# Out:
# 'No'

# %%
data[data['size'] > 3]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 4         24.59  3.61  Female     No   Sun  Dinner   4.0
# 5         25.29  4.71    Male     No     0  Dinner   4.0
# 7         26.88  3.12    Male     No   Sun  Dinner   4.0
# 11        35.26     5  Female     No   Sun  Dinner   4.0
# 13        18.43     3    Male     No   Sun  Dinner   4.0
# 23        39.42     0    Male     No   Sat  Dinner   4.0
# 25        17.81  2.34    Male      0   Sat  Dinner   4.0
# 31        18.35   2.5    Male     No   Sat  Dinner   4.0
# 33        20.69  2.45  Female     No   Sat  Dinner   4.0
# 44        30.40   5.6    Male     No   Sun  Dinner   4.0
# 47        32.40     6    Male     No   Sun  Dinner   4.0
# 52        34.81   5.2  Female     No   Sun  Dinner   4.0
# 54        25.56  4.34    Male     No   Sun  Dinner   4.0
# 56        38.01     3    Male    Yes   Sat  Dinner   4.0
# 59        48.27  6.73    Male     No   Sat  Dinner   4.0
# ...

# %%
data[['tip','sex']][data['size']<4]
# Out:
#         tip     sex
# 0    Female      No
# 1      1.66    Male
# 2       3.5    Male
# 3      Male      No
# 6         2    Male
# ..      ...     ...
# 239    5.92    Male
# 240       2  Female
# 241       2    Male
# 242    1.75    Male
# 243       3  Female
#
# [198 rows x 2 columns]

# %%
data.groupby('sex').count()
# Out:
#         total_bill  tip  smoker  day  time  size
# sex
# 0                2    2       2    2     2     2
# Female          85   85      85   85    85    85
# Male           154  154     154  154   154   154
# No               3    3       3    3     3     3

# %%
data['size'].max()
# Out:
# np.float64(6.0)

# %%
data['size'].min()
# Out:
# np.float64(0.0)

# %%
data['size'].mean()
# Out:
# np.float64(2.5450819672131146)

# %%
data['size'].sum()
# Out:
# np.float64(621.0)
